# %% [markdown]
# # Usando Tensores Para Manipular Imagens

# %%
import tensorflow as tf
import matplotlib.image as mp_image
import matplotlib.pyplot as plt

# %%
filename = "image.jpg"
input_image = mp_image.imread(filename)

# %%
# Dimensão
print ('\nDimensões da imagem: {}'.format(input_image.ndim))


# Shape
print ('\nShape da imagem: {}'.format(input_image.shape))
# Out:
# Dimensões da imagem: 3
#
# Shape da imagem: (2880, 5120, 3)

# %%
# Visualizando a imagem original
plt.imshow(input_image)
plt.show()

# %%
# Slice
slice = tf.slice(input_image,[10,0,0],[200,-1,-1])

print('\nSlice: ', slice)
print('\nShape do Slice: ', slice.shape)

plt.imshow(slice)
plt.show()
# Out:
# Slice:  tf.Tensor(
# [[[ 46   5   1]
#   [ 46   5   1]
#   [ 46   5   1]
#   ...
#   [  0   4  18]
#   [  0   0  14]
#   [  0   1  14]]
#
#  [[ 46   5   1]
#   [ 46   5   1]
#   [ 46   5   1]
#   ...
#   [  0   3  14]
#   [  0   0   9]
#   [  3   7  16]]
#
#  [[ 46   5   1]
#   [ 46   5   1]
#   [ 46   5   1]
#   ...
#   [  0   0   7]
#   [  0   0   5]
#   [  0   2   7]]
#
#  ...
#
#  [[ 52  11   5]
#   [ 52  11   5]
#   [ 52  11   5]
#   ...
#   [ 42  35  76]
#   [ 40  33  74]
#   [ 40  34  72]]
#
#  [[ 52  11   5]
#   [ 52  11   5]
#   [ 52  11   5]
#   ...
#   [ 51  35  98]
#   [ 52  36  99]
#   [ 56  40 103]]
#
#  [[ 52  11   5]
#   [ 52  11   5]
#   [ 52  11   5]
#   ...
#   [ 54  38 100]
#   [ 54  38 100]
#   [ 57  41 103]]], shape=(200, 5120, 3), dtype=uint8)
#
# Shape do Slice:  (200, 5120, 3)
